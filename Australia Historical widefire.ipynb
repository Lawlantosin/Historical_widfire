# %% [markdown]
# # Objectives
#
# After completing this lab you will be able to:
#
#  - Use visualization libraries such as Matplotlib, Pandas, Seaborn and Folium to create informative plots and charts

# %% [markdown]
# # Dataset
#
# **Historical Wildfires**
#
# This wildfire dataset contains data on fire activities in Australia starting from 2005. Additional information can be found [here](https://earthdata.nasa.gov/earth-observation-data/near-real-time/firms/c6-mcd14dl).
#
# Variables
#
# - Region: the 7 regions
# - Date: in UTC and provide the data for 24 hours ahead
# - Estimated_fire_area: daily sum of estimated fire area for presumed vegetation fires with a confidence > 75% for a each region in km2
# - Mean_estimated_fire_brightness: daily mean (by flagged fire pixels(=count)) of estimated fire brightness for presumed vegetation fires with a confidence level > 75% in Kelvin
# - Mean_estimated_fire_radiative_power: daily mean of estimated radiative power for presumed vegetation fires with a confidence level > 75% for a given region in megawatts
# - Mean_confidence: daily mean of confidence for presumed vegetation fires with a confidence level > 75%
# - Std_confidence: standard deviation of estimated fire radiative power in megawatts
# - Var_confidence: Variance of estimated fire radiative power in megawatts
# - Count: daily numbers of pixels for presumed vegetation fires with a confidence level of larger than 75% for a given region
# - Replaced: Indicates with an Y whether the data has been replaced with standard quality data when they are available (usually with a 2-3 month lag). Replaced data has a slightly higher quality in terms of locations

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df =pd.read_csv('Historical_Wildfires.csv')

# %%
df.head()
# Out:
#   Region      Date  Estimated_fire_area  Mean_estimated_fire_brightness  \
# 0    NSW  1/4/2005              8.68000                      312.266667
# 1    NSW  1/5/2005             16.61125                      322.475000
# 2    NSW  1/6/2005              5.52000                      325.266667
# 3    NSW  1/7/2005              6.26400                      313.870000
# 4    NSW  1/8/2005              5.40000                      337.383333
#
#    Mean_estimated_fire_radiative_power  Mean_confidence  Std_confidence  \
# 0                            42.400000        78.666667        2.886751
# 1                            62.362500        85.500000        8.088793
# 2                            38.400000        78.333333        3.214550
# 3                            33.800000        92.200000        7.529940
# 4                           122.533333        91.000000        7.937254
#
#    Var_confidence  Count Replaced
# 0        8.333333      3        R
# 1       65.428571      8        R
# 2       10.333333      3        R
# 3       56.700000      5        R
# 4       63.000000      3        R

# %%
df.shape
# Out:
# (26406, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26406 entries, 0 to 26405
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Region                               26406 non-null  object
#  1   Date                                 26406 non-null  object
#  2   Estimated_fire_area                  26406 non-null  float64
#  3   Mean_estimated_fire_brightness       26406 non-null  float64
#  4   Mean_estimated_fire_radiative_power  26406 non-null  float64
#  5   Mean_confidence                      26406 non-null  float64
#  6   Std_confidence                       24199 non-null  float64
#  7   Var_confidence                       24199 non-null  float64
#  8   Count                                26406 non-null  int64
#  9   Replaced                             26406 non-null  object
# dtypes: float64(6), int64(1), object(3)
# memory usage: 2.0+ MB

# %%
import datetime as dt

df['Year'] = pd.to_datetime(df['Date']).dt.year
df['Month'] = pd.to_datetime(df['Date']).dt.month

# %%
df
# Out:
#       Region        Date  Estimated_fire_area  Mean_estimated_fire_brightness  \
# 0        NSW    1/4/2005             8.680000                      312.266667
# 1        NSW    1/5/2005            16.611250                      322.475000
# 2        NSW    1/6/2005             5.520000                      325.266667
# 3        NSW    1/7/2005             6.264000                      313.870000
# 4        NSW    1/8/2005             5.400000                      337.383333
# ...      ...         ...                  ...                             ...
# 26401     WA  10/27/2020            32.970000                      324.068182
# 26402     WA  10/28/2020            20.840625                      314.425000
# 26403     WA  10/29/2020           136.083077                      323.588461
# 26404     WA  10/30/2020            42.397895                      324.205263
# 26405     WA  10/31/2020           107.370851                      330.057447
#
#        Mean_estimated_fire_radiative_power  Mean_confidence  Std_confidence  \
# 0                                42.400000        78.666667        2.886751
# 1                                62.362500        85.500000        8.088793
# 2                                38.400000        78.333333        3.214550
# 3                                33.800000        92.200000        7.529940
# 4                               122.533333        91.000000        7.937254
# ...                                    ...              ...             ...
# 26401                           103.318182        84.363636        5.277741
# 26402                            37.256250        88.312500        8.121730
# 26403                           294.102564        92.974359        8.282789
# 26404                            54.994737        89.631579        8.461107
# 26405                           201.625532        92.978723        7.266628
#
#        Var_confidence  Count Replaced  Year  Month
# 0            8.333333      3        R  2005      1
# 1           65.428571      8        R  2005      1
# 2           10.333333      3        R  2005      1
# 3           56.700000      5        R  2005      1
# 4           63.000000      3        R  2005      1
# ...               ...    ...      ...   ...    ...
# 26401       27.854545     11        N  2020     10
# 26402       65.962500     16        N  2020     10
# 26403       68.604588     39        N  2020     10
# 26404       71.590327     38        N  2020     10
# 26405       52.803885     47        N  2020     10
#
# [26406 rows x 12 columns]

# %% [markdown]
# ### VISUALIZATION

# %% [markdown]
# ##### To understand the change in average estimated fire area over time using pandas to plot the line chart.

# %%
df_new = df.groupby('Year')['Estimated_fire_area'].mean()

# %%
df_new.plot()
plt.xlabel('Year')
plt.ylabel('Average Estimated Fire Area (km²)')
plt.title('Estimated Fire Area over Time')
plt.show()

# %% [markdown]
# ##### To plot the estimated fire area over month

# %%
df_new = df.groupby(['Year', 'Month'])['Estimated_fire_area'].mean()
df_new.plot()
plt.xlabel('Year, Month')
plt.ylabel('Average Estimated Fire Area (km²)')
plt.title('Estimated Fire Area over Time')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### Use the functionality of seaborn to develop a barplot, to find the insights on the distribution of mean estimated fire brightness across the regions

# %%
df.Region.unique()
# Out:
# array(['NSW', 'NT', 'QL', 'SA', 'TA', 'VI', 'WA'], dtype=object)

# %%
sb.barplot(data =df, y='Mean_estimated_fire_brightness', x='Region')
plt.xlabel('Region')
plt.ylabel('Mean Estimated Fire Brightness (Kelvin)')
plt.title('Distribution of Mean Estimated Fire Brightness across Regions')
plt.show()

# %% [markdown]
# ##### Let's find the portion of count of pixels for presumed vegetation fires vary across regions<br> we will develop a pie chart for this

# %%
plt.figure(figsize=(15, 10))
region_counts = df.groupby('Region')['Count'].sum()
plt.pie(region_counts, labels=region_counts.index)
plt.title('Percentage of Pixels for Presumed Vegetation Fires by Region')
plt.legend([(i,round(k/region_counts.sum()*100,2)) for i,k in zip(region_counts.index, region_counts)])
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### Use Matplotlib to develop a histogram of the mean estimated fire brightness

# %%
plt.hist(x= 'Mean_estimated_fire_brightness', data=df, bins=20 )
plt.xlabel('Mean Estimated Fire Brightness (Kelvin)')
plt.ylabel('Count')
plt.title('Histogram of Mean Estimated Fire Brightness')
plt.show()

# %%
sb.histplot(data =df,x= 'Mean_estimated_fire_brightness', multiple='stack', hue='Region' )
plt.xlabel('Mean Estimated Fire Brightness (Kelvin)')
plt.ylabel('Count')
plt.title('Histogram of Mean Estimated Fire Brightness Across Region')
plt.show()

# %% [markdown]
# #####  Develop a scatter plot to find the correlation between mean estimated fire radiative power and mean confidence level

# %%
sb.scatterplot(data =df,y='Mean_estimated_fire_radiative_power',x= 'Mean_confidence')
plt.xlabel('Mean Estimated Fire Radiative Power (MW)')
plt.ylabel('Mean Confidence')
plt.title('Mean Estimated Fire Radiative Power vs. Mean Confidence')
plt.show()

# %% [markdown]
# ##### Let's mark these seven regions on the Map of Australia using Folium
# <br> we have created a dataframe for you containing the regions, their latitudes and longitudes. <br> For australia use [-25, 135] as location to create the map

# %%
import folium

# %%
region_data = {'region':['NSW','QL','SA','TA','VI','WA','NT'], 'Lat':[-31.8759835,-22.1646782,-30.5343665,-42.035067,-36.5986096,-25.2303005,-19.491411], 
               'Lon':[147.2869493,144.5844903,135.6301212,146.6366887,144.6780052,121.0187246,132.550964]}
reg=pd.DataFrame(region_data)
reg
# Out:
#   region        Lat         Lon
# 0    NSW -31.875984  147.286949
# 1     QL -22.164678  144.584490
# 2     SA -30.534367  135.630121
# 3     TA -42.035067  146.636689
# 4     VI -36.598610  144.678005
# 5     WA -25.230300  121.018725
# 6     NT -19.491411  132.550964

# %%
# instantiate a feature group 
aus_reg = folium.map.FeatureGroup()

# Create a Folium map centered on Australia
Aus_map = folium.Map(location=[-25, 135], zoom_start=4)

# loop through the region and add to feature group
for lat, lng, lab in zip(reg.Lat, reg.Lon, reg.region):
    aus_reg.add_child(
        folium.features.CircleMarker(
            [lat, lng],
            popup=lab,
            radius=5, # define how big you want the circle markers to be
            color='red',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# add incidents to map
Aus_map.add_child(aus_reg)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2ecae02dc4367fa62861c7a15bb79875 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2ecae02dc4367fa62861c7a15bb79875&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2ecae02dc4367fa62861c7a15bb79875 = L.map(
#                 &quot;map_2ecae02dc4367fa62861c7a15bb79875&quot;,
#                 {
#                     center: [-25.0, 135.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_244305ec16ae35b1a1a9c7ca5cec64f9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2ecae02dc4367fa62861c7a15bb79875);
#
#
#             var feature_group_66c312ac2939ffe30b8fe300a105ef81 = L.featureGroup(
#                 {}
#             ).addTo(map_2ecae02dc4367fa62861c7a15bb79875);
#
#
#             var circle_marker_5e81c8776f7a0036e656230f0a993ea5 = L.circleMarker(
#                 [-31.8759835, 147.2869493],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_66c312ac2939ffe30b8fe300a105ef81);
#
#
#         var popup_1c551ba33442776c323c7b15dbce103f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_09d1963d1a57ac02e3205eb0d7e40509 = $(`&lt;div id=&quot;html_09d1963d1a57ac02e3205eb0d7e40509&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NSW&lt;/div&gt;`)[0];
#                 popup_1c551ba33442776c323c7b15dbce103f.setContent(html_09d1963d1a57ac02e3205eb0d7e40509);
#
#
#
#         circle_marker_5e81c8776f7a0036e656230f0a993ea5.bindPopup(popup_1c551ba33442776c323c7b15dbce103f)
#         ;
#
#
#
#
#             var circle_marker_d79c8101e9481bef84e58742582ad0e8 = L.circleMarker(
#                 [-22.1646782, 144.5844903],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_66c312ac2939ffe30b8fe300a105ef81);
#
#
#         var popup_e5adf71f0a967c09769bf6f67da20a8d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a84b886dd1b495d41283f29eb20f316c = $(`&lt;div id=&quot;html_a84b886dd1b495d41283f29eb20f316c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;QL&lt;/div&gt;`)[0];
#                 popup_e5adf71f0a967c09769bf6f67da20a8d.setContent(html_a84b886dd1b495d41283f29eb20f316c);
#
#
#
#         circle_marker_d79c8101e9481bef84e58742582ad0e8.bindPopup(popup_e5adf71f0a967c09769bf6f67da20a8d)
#         ;
#
#
#
#
#             var circle_marker_1358c5f10186e4f58aecf00ea3ad43be = L.circleMarker(
#                 [-30.5343665, 135.6301212],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_66c312ac2939ffe30b8fe300a105ef81);
#
#
#         var popup_8824b2169f2610315d59ecbb15071d1f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c77eb71197241e0b96ecbe71c434c670 = $(`&lt;div id=&quot;html_c77eb71197241e0b96ecbe71c434c670&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;SA&lt;/div&gt;`)[0];
#                 popup_8824b2169f2610315d59ecbb15071d1f.setContent(html_c77eb71197241e0b96ecbe71c434c670);
#
#
#
#         circle_marker_1358c5f10186e4f58aecf00ea3ad43be.bindPopup(popup_8824b2169f2610315d59ecbb15071d1f)
#         ;
#
#
#
#
#             var circle_marker_752985c14283292ab02b5c3fdb68f430 = L.circleMarker(
#                 [-42.035067, 146.6366887],
